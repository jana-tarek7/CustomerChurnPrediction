# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from cleaning_preprocessing import clean_data ,preprocess_data
import pandas as pd
from EDA import Histogram , Boxplot ,heatmap ,Pairplot
df= pd.read_csv('churn.csv')
data= df.copy()
cleaned_data = clean_data(data)
numerical_cols = cleaned_data.select_dtypes(include=np.number).columns.tolist()
preprocessed_data= preprocess_data(cleaned_data)

# %%
Histogram(preprocessed_data)

# %%
Boxplot(preprocessed_data)

# %%
heatmap(preprocessed_data)

# %%
Pairplot(preprocessed_data)
